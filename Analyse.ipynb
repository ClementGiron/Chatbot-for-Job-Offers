# %%
import pandas as pd

pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 500)
filename = "lbc_halfcleaned_20170225sc.csv"
# Out:
# height has been deprecated.

# %%
df = pd.read_csv(filename, index_col=False)
df.head()
# Out:
#    Unnamed: 0                                  id                 date  \
# 0           0  ObjectId(585d58c917501629f7b7a475)  23 décembre à 17:44
# 1           1  ObjectId(585d58c917501629f7b7a476)  23 décembre à 17:35
# 2           2  ObjectId(585d58c917501629f7b7a477)  23 décembre à 17:35
# 3           3  ObjectId(585d58c917501629f7b7a478)  23 décembre à 17:32
# 4           4  ObjectId(585d58c917501629f7b7a479)  23 décembre à 17:34
#
#        siren                                               desc         ref  \
# 0  412481301  Nous cherchons le responsable financier &amp; ...      1612cu
# 1  433822053  SOCIETE   AMBIANCE  RECRUTE  UN  AGENT  DE  PR...         NaN
# 2  479482036  Nous sommes une petite boutique spécialisée da...         NaN
# 3  702011172  Securitas Accueil recherche un (e) hôte (sse) ...  LBCCaluire
# 4  343794731  Découvrez un métier :<br>Opératrice/opérateur ...         NaN
#
#                      commune                       formation  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'siren', 'desc', 'ref', 'commune',
#        'formation', 'sect', 'exp', 'salaire', 'tps', 'offre', 'contrat',
#        'fonction', 'sect_code', 'salaire_clean', 'commune_dep',
#        'commune_clean_', 'commune_clean', 'nomcommune', 'longitude',
#        'latitude', 'numrodpartement', 'desc_', 'salaire_temp', 'date_clean'],
#       dtype='object')

# %%
pd.options.display.max_colwidth = 1000

# %%
df["desc"]
# Out:
# 0        Nous cherchons le responsable financier &amp; administratif et comptable unique pour un PME à Nice, avec 10 - 20 salariés, dans le secteur services à l’automobile. <br>Vous travaillez de manière autonome avec des responsabilités suivantes : <br>- Tenue et la conformité légale et professionnelle des comptabilités générales jusqu’au bilan, de la paie et des obligations fiscales, sociales et administratives de la société, collaboration avec l’expert-comptable <br>- Contrôle et comptabilisation de caisse régistreuse<br>- Facturation et recouvrement de créances<br>- Tenue de comptabilité analytique pour les différentes activités avec budgets et reporting mensuel des principaux résultats et indicateurs de performance<br>- Organisation de classement, sauvegardes et archivages de la société ainsi que de ses bureaux et moyens administratifs et du réseau informatique (Ciel, Windows, serveur, mails)<br>- Support administratif de la fonction commerciale et du service client (assistance 
# ...
